# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (2.12.0)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (23.1.2)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.9)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.10)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.1)
# Requirement already satisfied: setuptools in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (60.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.55.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.37.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.18.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.3.0)
# Requirement already satisfied: urllib3<2.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.16)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (2.0.1)
# Requirement already satisfied: openpyxl in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: et-xmlfile in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (4.29.2)
# Requirement already satisfied: filelock in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (2023.5.5)
# Requirement already satisfied: requests in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: colorama in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from requests->transformers) (2023.5.7)

# %%
# !pip install tensorflow_hub
# Out:
# Requirement already satisfied: tensorflow_hub in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow_hub) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\taliya shitreet\pycharmprojects\ner\venv\lib\site-packages (from tensorflow_hub) (4.23.1)

# %% [markdown]
# ### IMPORT

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tensorflow.python.keras import metrics
import seaborn as sns

# %% [markdown]
# ### DATA PREPROCESSING

# %% [markdown]
# #### IMPORT & INFO
#  ORIGIN DATA - DATA WITH CAHTGPT LABALING

# %%
# Load the CSV file
data = pd.read_csv('GPTClassification.csv')
data.name = 'origin_df'
data.shape
# Out:
# (364, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  364 non-null    object
#  1   category  362 non-null    object
# dtypes: object(2)
# memory usage: 5.8+ KB

# %%
data.head(10)
# Out:
#                                             Sentence                  category
# 0  "I think there should be many various sitting ...                  Land use
# 1  "It should be distinctive but still matching t...            Local identity
# 2  "It should be clear where the entrance is and ...                  Land use
# 3  "well I think that the spaces should be focuse...  Land use, Future of work
# 4  "well it could be achieved through different m...                  Land use
# 5  "yes, the current building, as unsuitable as i...            Local identity
# 6  "maybe, however Im interested in your suggesti...                     other
# 7  "i find that a very correct approach... how di...                     other
# 8                                   "correct again "                     other
# 9  "well maybe it is a possibility to experiment ...            Local identity

# %% [markdown]
# #### CLEAN DATA

# %%
empty_string_count = (data['category'] == 'other').sum()
print("There is ", empty_string_count, " sentence that are not labeled")
# Out:
# There is  93  sentence that are not labeled

# %%
# delete the NuN values
data = data.dropna()

# %%
total_duplicate_titles = sum(data["Sentence"].duplicated())
print(f"There are {total_duplicate_titles} duplicate Sentences.")
# Out:
# There are 14 duplicate Sentences.

# %%
# Create a boolean mask for duplicated sentences
mask = data["Sentence"].duplicated(keep=False)
print("DUPLICATE ROWS")
# Print the rows with duplicated sentences
data[mask]
# Out:
# DUPLICATE ROWS
#                                      Sentence
# 17                                       "no"  \
# 51   "What spaces should be in the building?"
# 54     "What should the building look like? "
# 71   "What spaces should be in the building?"
# 74     "What should the building look like? "
# 85                                  "Hi Zaha"
# 97              "What would you like to know"
# 123                                  "spaces"
# 127                             "trees grass"
# 129                                  "spaces"
# 130                                 "history"
# 131                                 "history"
# 132                                  "spaces"
# 133                             "trees grass"
# 134                                  "modern"
# 135                                 "history"
# 139                            "not too high"
# 142                                    "safe"
# 144                                    "safe"
# 169             "What would you like to know"
# 191                                 "Hi Zaha"
# 216                                 "Hi Zaha"
# 242                                      "no"
# 247                                  "modern"
# 361                            "not too high"
#
#                                          category
# 17                                          other
# 51                       Future of work, Land use
# 54                                 Local identity
# 71                                       Land use
# 74                                 Local identity
# 85                                          other
# 97                                          other
# 123  Environment and climate resilience, Land use
# 127  Environment and climate resilience, Land use
# 129  Environment and climate resilience, Land use
# 130                                Local identity
# 131                                Local identity
# 132  Environment and climate resilience, Land use
# 133            Environment and climate resilience
# 134                                Local identity
# 135                                Local identity
# 139            Environment and climate resilience
# 142            Environment and climate resilience
# 144                                         other
# 169                                         other
# 191                                         other
# 216                                         other
# 242                                         other
# 247                                Local identity
# 361                                      Land use

# %%
data = data[~data["Sentence"].duplicated()]
print(f"duplicate rows:  {len(data)}")

# There are some categories with occurrence as low as 1.
print("categories upon once only:",sum(data["category"].value_counts() == 1))

# How many unique terms?
print("unique categories:",data["category"].nunique())
# Out:
# duplicate rows:  348
# categories upon once only: 14
# unique categories: 31

# %% [markdown]
# We need to handle the categories upon only once, its problematic for multi-label text classifier

# %%
def get_single_occurrence_categories(data):
    # Get the categories that appear only once
    single_occurrence_categories = data['category'].value_counts()
    single_occurrence_categories = single_occurrence_categories[single_occurrence_categories == 1].index

    # Get the rows where 'category' is in the list of single-occurrence categories
    once_sen = data[data['category'].isin(single_occurrence_categories)]
    return once_sen

# %%
print("sentences that their label is unique in the data set:")
once_sen = get_single_occurrence_categories(data)
once_sen
# Out:
# sentences that their label is unique in the data set:
#                                               Sentence
# 15   "hi, i think if there´s more free use co-worki...  \
# 19   "The building should be more open for the soci...
# 22   "To have a cafe on the ground floor would be n...
# 53                             "Can we have a garden?"
# 110  "I agree! Architecture students should be insp...
# 145  "The building should have several spaces for g...
# 183       "Can I 3d print infra lightweight concrete?"
# 194  "I think it should be more inviting compared t...
# 198  "There should be greenery aroud the building, ...
# 226  "I think that a good architecture school shoul...
# 239  "Hello Zaha, nice to meet you! I'm glad to be ...
# 316  "I hope in office room or big classroom there ...
# 325  "it should be 3-4 floors in height and have bo...
# 335  "Who's your favorite architect what's your fav...
#
#                                               category
# 15   Local identity, Environment and climate resili...
# 19   Local identity, Environment and climate resili...
# 22                Local identity, Mobility (transport)
# 53        Land use, Environment and climate resilience
# 110  Environment and climate resilience, Future of ...
# 145  Environment and climate resilience, Local iden...
# 183                           Future of work; Land use
# 194                           Local identity; Land use
# 198       Environment and climate resilience; Land use
# 226                           Land use; Local identity
# 239  Environment and climate resilience; Local iden...
# 316                                     Indoor comfort
# 325                     Mobility (transport), Land use
# 335               Mobility (transport), Local identity

# %%
# Replace ";" with ","
data['category'] = data['category'].str.replace(';', ',')

# %%
data["category"] = data["category"].apply(
    lambda x: x.split(', ')
)
data["category"].values[:5]
# Out:
# array([list(['Land use']), list(['Local identity']), list(['Land use']),
#        list(['Land use', 'Future of work']), list(['Land use'])],
#       dtype=object)

# %%
print("after replace ';', \nsentences that their label is unique in the data set: ")
once_sen = get_single_occurrence_categories(data)
once_sen
# Out:
# after replace ';',
# sentences that their label is unique in the data set:
#                                               Sentence
# 15   "hi, i think if there´s more free use co-worki...  \
# 19   "The building should be more open for the soci...
# 22   "To have a cafe on the ground floor would be n...
# 53                             "Can we have a garden?"
# 110  "I agree! Architecture students should be insp...
# 145  "The building should have several spaces for g...
# 239  "Hello Zaha, nice to meet you! I'm glad to be ...
# 316  "I hope in office room or big classroom there ...
# 335  "Who's your favorite architect what's your fav...
#
#                                               category
# 15   [Local identity, Environment and climate resil...
# 19   [Local identity, Environment and climate resil...
# 22              [Local identity, Mobility (transport)]
# 53      [Land use, Environment and climate resilience]
# 110  [Environment and climate resilience, Future of...
# 145  [Environment and climate resilience, Local ide...
# 239  [Environment and climate resilience, Local ide...
# 316                                   [Indoor comfort]
# 335             [Mobility (transport), Local identity]

# %% [markdown]
# The categories that appear once in the data we took from 14 to 9.
# Now for those 9 - we will separate them to different rows

# %%
# Create a list to store the new rows
new_rows = []

# Iterate over the rows in the dataframe where category is in single_occurrence_categories
for idx, row in once_sen.iterrows():
    # Iterate over the categories in the 'category' column
    for cat in row['category']:
        new_row = {'Sentence': row['Sentence'], 'category': [cat]}
        # Only add the new row if it is not already in new_rows
        if new_row not in new_rows:
            new_rows.append(new_row)
    data = data.drop(idx)

# Create a new DataFrame from the new rows
new_rows_df = pd.DataFrame(new_rows)

# Append the new rows to the dataframe using concat
data = pd.concat([data, new_rows_df], ignore_index=True)

# %%
# Convert lists in 'category' to tuples
new_rows_df['category'] = new_rows_df['category'].apply(tuple)

# Then check for duplicates
total_duplicate_titles = new_rows_df.duplicated().sum()
print(f"There are {total_duplicate_titles} duplicates.")
# Out:
# There are 0 duplicates.

# %%
# There are some categories with occurrence as low as 1.
print(once_sen['Sentence'][19])
data[data['Sentence'] == once_sen['Sentence'][19]]
# this cell for checking it was separated
# Out:
# "The building should be more open for the society."
#                                               Sentence
# 342  "The building should be more open for the soci...  \
# 343  "The building should be more open for the soci...
#
#                                  category
# 342                      [Local identity]
# 343  [Environment and climate resilience]

# %%
data.shape
# Out:
# (361, 2)

# %%
# Get the categories that appear more than once
multi_occurrence_categories = data['category'].value_counts()
multi_occurrence_categories = multi_occurrence_categories[multi_occurrence_categories > 1].index

# Filter the data to only include rows where 'category' is in the list of multi-occurrence categories
data = data[data['category'].isin(multi_occurrence_categories)]

# %%
data.shape
# Out:
# (360, 2)

# %% [markdown]
# #### SPLIT DATA - train, validation, test

# %%
test_split = 0.2


# Initial train and test split.
train_df, test_df = train_test_split(
    data,
    test_size=test_split,
    stratify=data["category"].values,
    random_state=42
)

# Splitting the test set further into validation
# and new test sets.
val_df = test_df.sample(frac=0.5)
test_df.drop(val_df.index, inplace=True)

print(f"Number of rows in training set: {len(train_df)}")
print(f"Number of rows in validation set: {len(val_df)}")
print(f"Number of rows in test set: {len(test_df)}")
# Out:
# Number of rows in training set: 288
# Number of rows in validation set: 36
# Number of rows in test set: 36

# %% [markdown]
# #### MULTI HOT ENCODING
# We will convert the  categorical data into a form that can be used by deep learning models.
# because we are dealing with multi-label classification problem.

# %%
# Convert tensors to numpy arrays and then to sets of tuples for set operations
train_categories_tensor = tf.ragged.constant(train_df["category"].values)
test_categories_tensor = tf.ragged.constant(test_df["category"].values)

train_categories = set(tuple(x) for x in train_categories_tensor.to_list())
test_categories = set(tuple(x) for x in test_categories_tensor.to_list())

categories_not_in_train = test_categories - train_categories

print(categories_not_in_train)
# Out:
# set()

# %% [markdown]
# the result is an empty set (set())- it means there are no categories that exist in the test set but not in the training set

# %%
categories = tf.ragged.constant(train_df["category"].values)
lookup = tf.keras.layers.StringLookup(output_mode="multi_hot", num_oov_indices=0)
lookup.adapt(categories)
vocab = lookup.get_vocabulary()


def invert_multi_hot(encoded_labels):
    """Reverse a single multi-hot encoded label to a tuple of vocab terms."""
    hot_indices = np.argwhere(encoded_labels == 1.0)[..., 0]
    return np.take(vocab, hot_indices)


print("Vocabulary:\n")
print(vocab)
# Out:
# Vocabulary:
#
# ['Land use', 'other', 'Environment and climate resilience', 'Local identity', 'Future of work', 'Mobility (transport)']

# %%
sample_label = train_df["category"].iloc[0]
print(f"Original label: {sample_label}")

label_binarized = lookup([sample_label])
print(f"Label-binarized representation: {label_binarized}")
# Out:
# Original label: ['other']
# Label-binarized representation: [[0. 1. 0. 0. 0. 0.]]

# %%
train_df["Sentence"].apply(lambda x: len(x.split(" "))).describe()
# Out:
# count    288.000000
# mean      13.385417
# std       22.621890
# min        1.000000
# 25%        5.000000
# 50%        8.000000
# 75%       14.000000
# max      179.000000
# Name: Sentence, dtype: float64

# %% [markdown]
#  the 75th percentile is at 13, meaning that 75% of the sentences have a length of 13 or less.
#  and the maximum length observed is 179

# %% [markdown]
# #### MAKE DATASET OBJECT FROM DF

# %%
max_seqlen = 20
batch_size = 128
padding_token = "<pad>"
auto = tf.data.AUTOTUNE


def make_dataset(dataframe, is_train=True):
    labels = tf.ragged.constant(dataframe["category"].values)
    label_binarized = lookup(labels).numpy()
    sentences = dataframe["Sentence"].values
    dataset = tf.data.Dataset.from_tensor_slices(
        (sentences, label_binarized)
    )
    dataset = dataset.shuffle(batch_size * 10) if is_train else dataset
    return dataset.batch(batch_size)

# %%
train_dataset = make_dataset(train_df, is_train=True)
validation_dataset = make_dataset(val_df, is_train=False)
test_dataset = make_dataset(test_df, is_train=False)

# %% [markdown]
# #### DATA DISTRIBUTION

# %%
from collections import Counter

def label_distribution(df):
    flat_categories = [category for sublist in df["category"] for category in sublist]
    counts = Counter(flat_categories)
    print("distribution:")
    for category, count in counts.items():
        print(f"{category}: {count}")
    print("")

# %%
print("DATA")
label_distribution(data)
pd.DataFrame(data["Sentence"].apply(lambda x: len(x.split(" "))).describe())
# Out:
# DATA
# distribution:
# Land use: 108
# Local identity: 73
# Future of work: 48
# other: 88
# Environment and climate resilience: 76
# Mobility (transport): 12
#          Sentence
# count  360.000000
# mean    13.208333
# std     22.649772
# min      1.000000
# 25%      5.000000
# 50%      8.000000
# 75%     13.000000
# max    179.000000

# %%
print("TRAIN")
label_distribution(train_df)
pd.DataFrame(train_df["Sentence"].apply(lambda x: len(x.split(" "))).describe())
# Out:
# TRAIN
# distribution:
# other: 70
# Mobility (transport): 10
# Land use: 86
# Environment and climate resilience: 61
# Local identity: 59
# Future of work: 39
#          Sentence
# count  288.000000
# mean    13.385417
# std     22.621890
# min      1.000000
# 25%      5.000000
# 50%      8.000000
# 75%     14.000000
# max    179.000000

# %%
print("\nVAL")
label_distribution(val_df)
pd.DataFrame(val_df["Sentence"].apply(lambda x: len(x.split(" "))).describe())
# Out:
# VAL
# distribution:
# other: 10
# Land use: 9
# Environment and climate resilience: 7
# Future of work: 6
# Local identity: 7
#         Sentence
# count  36.000000
# mean   11.805556
# std    14.887808
# min     1.000000
# 25%     5.000000
# 50%     9.000000
# 75%    12.250000
# max    87.000000

# %%
print("\nTEST")
label_distribution(test_df)
pd.DataFrame(test_df["Sentence"].apply(lambda x: len(x.split(" "))).describe())
# Out:
# TEST
# distribution:
# other: 8
# Local identity: 7
# Land use: 13
# Mobility (transport): 2
# Environment and climate resilience: 8
# Future of work: 3
#          Sentence
# count   36.000000
# mean    13.194444
# std     29.013120
# min      1.000000
# 25%      4.750000
# 50%      7.000000
# 75%     12.250000
# max    179.000000

# %%
print("EXAMPLE OF HOT-ENCODING")
text_batch, label_batch = next(iter(train_dataset))

for i, text in enumerate(text_batch[1:2]):
    label = label_batch[i].numpy()[None, ...]
    print(label[0])
    print(f"Abstract: {text}")
    print(f"Label(s): {invert_multi_hot(label[0])}")
    print(" ")
# Out:
# EXAMPLE OF HOT-ENCODING
# [0. 0. 1. 0. 0. 0.]
# Abstract: b'"there should be canteen spaces for people to make their own food"'
# Label(s): ['Environment and climate resilience']

# %%
vocabulary = set()
train_df["Sentence"].str.lower().str.split().apply(vocabulary.update)
vocabulary_size = len(vocabulary)
print("vocabulary_size: ",vocabulary_size)
# Out:
# vocabulary_size:  1090

# %% [markdown]
# ### BERT MODEL

# %%
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf

tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')
model = TFBertModel.from_pretrained('bert-base-multilingual-uncased')

def get_bert_embeddings_py(text, label):
    # Convert tensor to list
    text = [t.decode('utf-8') for t in text.numpy()]
    inputs = tokenizer(text, max_length=max_seqlen, padding="max_length", truncation=True, return_tensors="tf")
    outputs = model(inputs)
    sentence_representation = outputs[1]
    return (sentence_representation.numpy(), label.numpy())

def tf_get_bert_embeddings(text, label):
    [rep, label] = tf.py_function(get_bert_embeddings_py, [text, label], [tf.float32, label.dtype])
    rep.set_shape((None, 768))  # 768 is the size of BERT embeddings. Adjust if you are using a different model
    return rep, label

train_dataset = train_dataset.map(tf_get_bert_embeddings, num_parallel_calls=auto).prefetch(auto)
validation_dataset = validation_dataset.map(tf_get_bert_embeddings, num_parallel_calls=auto).prefetch(auto)
test_dataset = test_dataset.map(tf_get_bert_embeddings, num_parallel_calls=auto).prefetch(auto)
# Out:
# Some layers from the model checkpoint at bert-base-multilingual-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-multilingual-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %% [markdown]
# ### Create a text classification Model

# %%
from tensorflow.keras import layers
def make_model():
    mlp_model = tf.keras.Sequential(
        [
            layers.Dense(512, activation="relu"),
            layers.Dense(256, activation="relu"),
            layers.Dense(128, activation="relu"),
            layers.Dense(64, activation="relu"),
            layers.Dense(lookup.vocabulary_size(), activation="sigmoid"),
        ]  # More on why "sigmoid" has been used here in a moment.
    )
    return mlp_model

# %% [markdown]
# ## Train the model

# %% [markdown]
# #### class to evaluate the model

# %%
class F1Score(metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super().__init__(name=name, **kwargs)
        self.precision = metrics.Precision()
        self.recall = metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def reset_state(self):
        self.precision.reset_state()
        self.recall.reset_state()

    def result(self):
       precision = self.precision.result()
       recall = self.recall.result()
       return 2 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))

# %%
epochs = 16

shallow_mlp_model = make_model()
shallow_mlp_model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=[
        "binary_accuracy", #"binary_accuracy" checks for each position if the prediction is correct.
        metrics.Precision(name='precision'),
        metrics.Recall(name='recall'),
        F1Score()
    ]
)

history = shallow_mlp_model.fit(
    train_dataset, validation_data=validation_dataset, epochs=epochs
)
# Out:
# Epoch 1/16
# 3/3 [==============================] - 14s 1s/step - loss: 0.6187 - binary_accuracy: 0.7008 - precision: 0.2333 - recall: 0.3201 - f1_score: 0.2683 - val_loss: 0.4737 - val_binary_accuracy: 0.8194 - val_precision: 0.2474 - val_recall: 0.2582 - val_f1_score: 0.2527
# Epoch 2/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4711 - binary_accuracy: 0.8113 - precision: 0.2467 - recall: 0.1542 - f1_score: 0.1890 - val_loss: 0.4644 - val_binary_accuracy: 0.8194 - val_precision: 0.2467 - val_recall: 0.1291 - val_f1_score: 0.1695
# Epoch 3/16
# 3/3 [==============================] - 11s 1s/step - loss: 0.4773 - binary_accuracy: 0.8119 - precision: 0.2467 - recall: 0.0966 - f1_score: 0.1387 - val_loss: 0.4539 - val_binary_accuracy: 0.8194 - val_precision: 0.2467 - val_recall: 0.0861 - val_f1_score: 0.1276
# Epoch 4/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4604 - binary_accuracy: 0.8137 - precision: 0.2526 - recall: 0.0728 - f1_score: 0.1130 - val_loss: 0.4457 - val_binary_accuracy: 0.8194 - val_precision: 0.2552 - val_recall: 0.0680 - val_f1_score: 0.1074
# Epoch 5/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4514 - binary_accuracy: 0.8131 - precision: 0.2637 - recall: 0.0611 - f1_score: 0.0992 - val_loss: 0.4408 - val_binary_accuracy: 0.8194 - val_precision: 0.2638 - val_recall: 0.0577 - val_f1_score: 0.0947
# Epoch 6/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4491 - binary_accuracy: 0.8119 - precision: 0.2652 - recall: 0.0512 - f1_score: 0.0859 - val_loss: 0.4335 - val_binary_accuracy: 0.8194 - val_precision: 0.2650 - val_recall: 0.0485 - val_f1_score: 0.0820
# Epoch 7/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4426 - binary_accuracy: 0.8119 - precision: 0.2650 - recall: 0.0435 - f1_score: 0.0748 - val_loss: 0.4353 - val_binary_accuracy: 0.8194 - val_precision: 0.2650 - val_recall: 0.0416 - val_f1_score: 0.0719
# Epoch 8/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4442 - binary_accuracy: 0.8119 - precision: 0.2703 - recall: 0.0393 - f1_score: 0.0686 - val_loss: 0.4377 - val_binary_accuracy: 0.8148 - val_precision: 0.2712 - val_recall: 0.0385 - val_f1_score: 0.0674
# Epoch 9/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4395 - binary_accuracy: 0.8148 - precision: 0.2835 - recall: 0.0381 - f1_score: 0.0672 - val_loss: 0.4330 - val_binary_accuracy: 0.8194 - val_precision: 0.2850 - val_recall: 0.0372 - val_f1_score: 0.0659
# Epoch 10/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4365 - binary_accuracy: 0.8142 - precision: 0.2924 - recall: 0.0360 - f1_score: 0.0641 - val_loss: 0.4320 - val_binary_accuracy: 0.8194 - val_precision: 0.2936 - val_recall: 0.0352 - val_f1_score: 0.0628
# Epoch 11/16
# 3/3 [==============================] - 11s 1s/step - loss: 0.4346 - binary_accuracy: 0.8131 - precision: 0.2967 - recall: 0.0335 - f1_score: 0.0602 - val_loss: 0.4322 - val_binary_accuracy: 0.8194 - val_precision: 0.2977 - val_recall: 0.0327 - val_f1_score: 0.0590
# Epoch 12/16
# 3/3 [==============================] - 11s 1s/step - loss: 0.4308 - binary_accuracy: 0.8137 - precision: 0.3039 - recall: 0.0319 - f1_score: 0.0577 - val_loss: 0.4303 - val_binary_accuracy: 0.8148 - val_precision: 0.3053 - val_recall: 0.0316 - val_f1_score: 0.0573
# Epoch 13/16
# 3/3 [==============================] - 12s 1s/step - loss: 0.4287 - binary_accuracy: 0.8160 - precision: 0.3224 - recall: 0.0335 - f1_score: 0.0606 - val_loss: 0.4277 - val_binary_accuracy: 0.8148 - val_precision: 0.3286 - val_recall: 0.0344 - val_f1_score: 0.0624
# Epoch 14/16
# 3/3 [==============================] - 11s 1s/step - loss: 0.4259 - binary_accuracy: 0.8160 - precision: 0.3456 - recall: 0.0368 - f1_score: 0.0665 - val_loss: 0.4239 - val_binary_accuracy: 0.8148 - val_precision: 0.3487 - val_recall: 0.0371 - val_f1_score: 0.0670
# Epoch 15/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4220 - binary_accuracy: 0.8212 - precision: 0.3688 - recall: 0.0398 - f1_score: 0.0719 - val_loss: 0.4224 - val_binary_accuracy: 0.8102 - val_precision: 0.3750 - val_recall: 0.0412 - val_f1_score: 0.0743
# Epoch 16/16
# 3/3 [==============================] - 10s 1s/step - loss: 0.4192 - binary_accuracy: 0.8183 - precision: 0.3909 - recall: 0.0443 - f1_score: 0.0796 - val_loss: 0.4251 - val_binary_accuracy: 0.8148 - val_precision: 0.3943 - val_recall: 0.0448 - val_f1_score: 0.0805

# %%
# Save the model
shallow_mlp_model.save('model_text_clf_bert_80_FINAL.h5')

# %%
def plot_evaluate(model):
    def plot_result(item):
        plt.plot(model.history.history[item], label=item)
        plt.plot(model.history.history["val_" + item], label="val_" + item)
        plt.xlabel("Epochs")
        plt.ylabel(item)
        plt.title("Train and Validation {} Over Epochs".format(item), fontsize=14)
        plt.legend()
        plt.grid()
        plt.show()

        last_train_result = model.history.history[item][-1]
        last_val_result = model.history.history["val_" + item][-1]
        print("Last {} (train): {:.4f}".format(item, last_train_result))
        print("Last {} (validation): {:.4f}".format(item, last_val_result))

    plot_result("loss")
    plot_result("binary_accuracy")
    plot_result("precision")
    plot_result("recall")
    plot_result("f1_score")

# %%
test_df.to_csv("test_df_80.csv", index=False)

# %%
plot_evaluate(shallow_mlp_model)
# Out:
# Last loss (train): 0.4192
# Last loss (validation): 0.4251
# Last binary_accuracy (train): 0.8183
# Last binary_accuracy (validation): 0.8148
# Last precision (train): 0.3909
# Last precision (validation): 0.3943
# Last recall (train): 0.0443
# Last recall (validation): 0.0448
# Last f1_score (train): 0.0796
# Last f1_score (validation): 0.0805

# %% [markdown]
# ### Test part:
# 1. Predict labels for the test set using the model.
# 2. Convert these predicted probabilities to binary format (0 or 1) using a threshold of 0.5.
# 3. For each category:
# * Extract the true and predicted labels for this category.
# * Calculate and print the accuracy, precision, recall, and F1 score.
# * Calculate and plot a confusion matrix for the category.

# %%
# Generate predictions on the test set
y_pred = shallow_mlp_model.predict(test_dataset)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
def custom_round(y_pred, threshold=0.5):
    binary_predictions = np.zeros_like(y_pred)

    for i, row in enumerate(y_pred):
        if np.all(row < threshold):
            binary_predictions[i, np.argmax(row)] = 1
        else:
            binary_predictions[i] = np.round(row)

    return binary_predictions

binary_predictions = custom_round(y_pred, threshold=0.5)

# %%
y_true = np.vstack(test_dataset.map(lambda x, y: y).as_numpy_iterator())
# Out:
# C:\Users\taliya shitreet\AppData\Local\Temp\ipykernel_21216\97231176.py:1: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   y_true = np.vstack(test_dataset.map(lambda x, y: y).as_numpy_iterator())

# %%
from sklearn.metrics import confusion_matrix

for i in range(binary_predictions.shape[1]):
    print(f"Category {i+1}:\n")
    true_labels = y_true[:, i]
    predicted_labels = binary_predictions[:, i]

    # Calculate metrics
    accuracy = metrics.BinaryAccuracy()(true_labels, predicted_labels)
    precision = metrics.Precision()(true_labels, predicted_labels)
    recall = metrics.Recall()(true_labels, predicted_labels)
    f1 = F1Score()(true_labels, predicted_labels)

    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1 Score: {f1}\n")

    # Plot confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)  # Note: confusion_matrix is not available in tf.keras.metrics
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title(f'Confusion matrix for category {i+1}')
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()
# Out:
# Category 1:
#
# Accuracy: 0.6388888955116272
# Precision: 0.5
# Recall: 0.692307710647583
# F1 Score: 0.5806450843811035
# Category 2:
#
# Accuracy: 0.7222222089767456
# Precision: 0.4166666567325592
# Recall: 0.625
# F1 Score: 0.4999999403953552
# Category 3:
#
# Accuracy: 0.6111111044883728
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Category 4:
#
# Accuracy: 0.8055555820465088
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Category 5:
#
# Accuracy: 0.9166666865348816
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Category 6:
#
# Accuracy: 0.9444444179534912
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0

# %%
# After training your model, evaluate it on the test data
test_metrics = shallow_mlp_model.evaluate(test_dataset, verbose=0)

# The metrics returned by model.evaluate() are in the same order they were added when compiling the model
print("Test Loss: ", test_metrics[0])
print("Test Binary Accuracy: ", test_metrics[1])
print("Test Precision: ", test_metrics[2])
print("Test Recall: ", test_metrics[3])
print("Test F1 Score: ", test_metrics[4])
# Out:
# Test Loss:  0.45214688777923584
# Test Binary Accuracy:  0.8240740299224854
# Test Precision:  0.3973013460636139
# Test Recall:  0.04518328979611397
# Test F1 Score:  0.0811389908194542

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ### DISTRUBIOTION
#  Lets check for the train and test data how many samples we have from each class:

# %%
from collections import Counter

# Flatten the list of categories
flat_categories = [category for sublist in train_df["category"] for category in sublist]

# Count the occurrences
counts = Counter(flat_categories)

# Print counts in a readable format
for category, count in counts.items():
    print(f" {category}: {count}")
# Out:
#  other: 70
#  Mobility (transport): 10
#  Land use: 86
#  Environment and climate resilience: 61
#  Local identity: 59
#  Future of work: 39

# %%
# Flatten the list of categories
flat_categories = [category for sublist in test_df["category"] for category in sublist]

# Count the occurrences
counts = Counter(flat_categories)

# Print counts in a readable format
for category, count in counts.items():
    print(f" {category}: {count}")
# Out:
#  other: 8
#  Local identity: 7
#  Land use: 13
#  Mobility (transport): 2
#  Environment and climate resilience: 8
#  Future of work: 3
